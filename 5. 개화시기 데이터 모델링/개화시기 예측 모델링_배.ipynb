# %% [markdown]
# # 기본 세팅

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (9,508 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 120895 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
! pip install catboost
! pip install optuna
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2
# Collecting optuna
#   Downloading optuna-3.3.0-py3-none-any.whl (404 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 4.3 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.12.0-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 kB 21.2 MB/s eta 0:00:00
# Collecting cmaes>=0.10.0 (from optuna)
#   Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.20)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.12.0 cmaes-0.10.0 colorlog-6.7.0 optuna-3.3.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import numpy as np
import random
import os
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)


from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import lightgbm as lgb
import catboost as cb
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor
from tqdm import tqdm
from sklearn.metrics import mean_absolute_error
from sklearn.svm import SVR
from sklearn import linear_model
from sklearn.linear_model import ElasticNet
from catboost import CatBoostRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import DotProduct, WhiteKernel
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import RobustScaler
from scipy.signal import savgol_filter
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler  # 표준화 패키지 라이브러리
from sklearn.decomposition import PCA

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import optuna
from optuna import Trial
from optuna.samplers import TPESampler
from sklearn.preprocessing import MinMaxScaler

import warnings

# 모든 경고 메시지 끄기
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'NanumBarunGothic' # 나눔바른고딕 적용하기

# %%
peach = pd.read_csv('/content/drive/MyDrive/복숭아 개화 데이터.csv',encoding='cp949')
pear = pd.read_csv('/content/drive/MyDrive/배 개화 데이터.csv',encoding='cp949')

# %%
peach['지점'].unique()
# Out:
# array(['강릉', '대관령', '동해', '북강릉', '북춘천', '삼척', '속초', '영월', '원주', '인제',
#        '철원', '춘천', '태백', '홍천', '동두천', '수원', '양평', '이천', '파주', '거제', '거창',
#        '남해', '밀양', '산청', '진주', '창원', '통영', '합천', '구미', '문경', '봉화', '상주',
#        '안동', '영덕', '영주', '영천', '울릉도', '울진', '의성', '포항', '광주', '대구',
#        '대구(기)', '대전', '부산', '서울', '울산', '강화', '백령도', '인천', '고흥', '목포',
#        '무안', '순천', '여수', '완도', '장흥', '주암', '진도(첨찰산)', '해남', '흑산도', '고창',
#        '고창군', '군산', '남원', '부안', '임실', '장수', '전주', '정읍', '고산', '서귀포', '성산',
#        '성산포', '제주', '금산', '보령', '부여', '서산', '천안', '홍성', '보은', '제천', '청주',
#        '추풍령', '충주'], dtype=object)

# %% [markdown]
# # X변수 Y변수 지정

# %%
data= pear.copy()
x_col=[ '위도', '경도', '고도', '2_일강수량(mm)_sum', '3_일강수량(mm)_sum',
       '2_최고기온(°C)_max', '3_최고기온(°C)_max', '2_최고기온(°C)_mean',
       '3_최고기온(°C)_mean', '2_최고기온(°C)_min', '3_최고기온(°C)_min', '2_최저기온(°C)_max',
       '3_최저기온(°C)_max', '2_최저기온(°C)_mean', '3_최저기온(°C)_mean',
       '2_최저기온(°C)_min', '3_최저기온(°C)_min', '2_평균기온(°C)_max', '3_평균기온(°C)_max',
       '2_평균기온(°C)_mean', '3_평균기온(°C)_mean', '2_평균기온(°C)_min',
       '3_평균기온(°C)_min', '2_합계 일조시간(hr)_sum', '3_합계 일조시간(hr)_sum']
y_col='365'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9d6f440aadd2> in <cell line: 1>()
# ----> 1 data= pear.copy()
#       2 x_col=[ '위도', '경도', '고도', '2_일강수량(mm)_sum', '3_일강수량(mm)_sum',
#       3        '2_최고기온(°C)_max', '3_최고기온(°C)_max', '2_최고기온(°C)_mean',
#       4        '3_최고기온(°C)_mean', '2_최고기온(°C)_min', '3_최고기온(°C)_min', '2_최저기온(°C)_max',
#       5        '3_최저기온(°C)_max', '2_최저기온(°C)_mean', '3_최저기온(°C)_mean',
#
# NameError: name 'pear' is not defined

# %% [markdown]
# #모델 세팅

# %%
models = {'rf': RandomForestRegressor(random_state=0), #랜포

          'xgbr':xgb.XGBRegressor(),# xgb

          'lgbm':lgb.LGBMRegressor(force_col_wise=True), #lgbm

          'svr': SVR(), #svr

          'ard': linear_model.ARDRegression(),#ard

          'bayesian_ridge': linear_model.BayesianRidge(),#ridge

          'lasso': linear_model.Lasso(alpha=0),#lasso

          'cbr': CatBoostRegressor(verbose=False), #catboost

          'etr': ExtraTreeRegressor(random_state=0,max_depth=100), # extra tree regressor

          'mlp': MLPRegressor(random_state=1, max_iter=1000), # MLP

          'ada': AdaBoostRegressor(random_state=0), # AdaBoost Regressor

          'sgdr' : make_pipeline(StandardScaler(),
                     SGDRegressor(max_iter=1000, tol=1e-3)),# SGDRegressor

          'knn' : KNeighborsRegressor(n_neighbors=5), # KNeighborsRegressor

          'hgbr' : HistGradientBoostingRegressor(),

          'ols':LinearRegression() }

# %%
class regressor:
    def __init__(self, model1=None, model2=None):
        if model1 is None:
            self.model1 = CatBoostRegressor(verbose=False,has_time=True,random_state=6)
        else:
            self.model1 = model1

        if model2 is None:
            self.model2 = lgb.LGBMRegressor(random_state=6)
        else:
            self.model2 = model2

        self.model3 = None
        self.model4 = None

    def fit(self, x_train, y_train):
        # 1차 적합
        self.model1.fit(x_train,y_train)
        train_fitted_values = self.model1.predict(x_train)
        train_residual = y_train - train_fitted_values

        # 2차 적합
        self.model2.fit(x_train, train_residual)
        train_fitted_values2 = self.model2.predict(x_train)
        train_residual2 = train_residual - train_fitted_values2

        # 3차 적합
        self.model3 = lgb.LGBMRegressor(random_state=6)
        self.model3.fit(x_train, train_residual2)
        train_fitted_values3 = self.model3.predict(x_train)
        train_residual3 = train_residual2 - train_fitted_values3

        # 4차 적합
        self.model4 = lgb.LGBMRegressor(random_state=6)
        self.model4.fit(x_train, train_residual3)

    def predict(self, x_test):
        test_fitted_values = self.model1.predict(x_test)
        test_fitted_values2 = self.model2.predict(x_test)
        test_fitted_values3 = self.model3.predict(x_test)
        test_residual = self.model4.predict(x_test)

        return test_fitted_values + test_fitted_values2 + test_fitted_values3 + test_residual

    def evaluate(self, x_test, y_test):
        y_pred = self.predict(x_test)
        score = mean_absolute_error(y_test, y_pred)
        return score

# %%
reg = regressor(model1=models['cbr'],model2=models['rf'])

# %% [markdown]
# # 교차검증을 통한 모델의 성능 확인

# %%
def cv(model,x_data,y_data,metric='both'):
  X = x_data
  y = y_data

  kf = KFold(n_splits=5, shuffle=True, random_state=42)

  mae_scores = []
  rmse_scores = []

  for train_index, test_index in kf.split(X):
      X_train, X_test = X.iloc[train_index], X.iloc[test_index]
      y_train, y_test = y.iloc[train_index], y.iloc[test_index]

      model.fit(X_train, y_train)

      y_pred = model.predict(X_test)

      mae = mean_absolute_error(y_test, y_pred)
      rmse = np.sqrt(mean_squared_error(y_test, y_pred))

      mae_scores.append(mae)
      rmse_scores.append(rmse)

  mean_mae = np.mean(mae_scores)
  mean_rmse = np.mean(rmse_scores)

  score = {'mae': mean_mae,'rmse':mean_rmse }

  if metric == 'both':
    result = score
  else:
    result = score[metric]

  return result

# %%
for model in models.keys():
  score = cv(x_data=data[x_col],y_data=data[y_col],model=models[model])
  print(f'{model}: {score}')
# Out:
# rf: {'mae': 3.542419610985649, 'rmse': 4.878919710736621}
# xgbr: {'mae': 3.721908372662407, 'rmse': 5.002297709364987}
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 4576
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score 102.155091
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 4562
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score 102.132165
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 4576
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score 101.765341
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 4568
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score 102.181389
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 4555
# [LightGBM] [Info] Number of data points in the train set: 1484, number of used features: 26
# [LightGBM] [Info] Start training from score 102.043801
# lgbm: {'mae': 3.543683109769984, 'rmse': 4.838971108222077}
# svr: {'mae': 5.530619003699043, 'rmse': 7.230332695955637}
# ard: {'mae': 3.7563008799309374, 'rmse': 5.100322366504442}
# bayesian_ridge: {'mae': 3.7431699229335704, 'rmse': 5.088626949553012}
# lasso: {'mae': 3.7482849431385397, 'rmse': 5.0906113733525356}
# cbr: {'mae': 3.402344258866001, 'rmse': 4.67512671008963}
# etr: {'mae': 4.902401107306768, 'rmse': 6.584745474628863}
# mlp: {'mae': 3.9448453710741243, 'rmse': 5.294508036077218}
# ada: {'mae': 4.300766981379453, 'rmse': 5.627531256879934}
# sgdr: {'mae': 3.7405904393407106, 'rmse': 5.099312357200846}
# knn: {'mae': 5.177243971734538, 'rmse': 6.6452771659942345}
# hgbr: {'mae': 3.5289750148898698, 'rmse': 4.826025391085372}
# ols: {'mae': 3.748385061929509, 'rmse': 5.090636685123718}

# %%
cv(x_data=data[x_col],y_data=data[y_col],model=reg)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000182 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4576
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score -0.001883
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000538 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4576
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000663 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4562
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score 0.005836
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000146 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4562
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000251 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4576
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score -0.001932
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000576 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4576
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000172 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4568
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score 0.001585
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000555 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4568
# [LightGBM] [Info] Number of data points in the train set: 1483, number of used features: 26
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000605 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4555
# [LightGBM] [Info] Number of data points in the train set: 1484, number of used features: 26
# [LightGBM] [Info] Start training from score 0.005184
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000514 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4555
# [LightGBM] [Info] Number of data points in the train set: 1484, number of used features: 26
# [LightGBM] [Info] Start training from score 0.000000
# {'mae': 3.407742482930317, 'rmse': 4.68537151725494}

# %% [markdown]
# # 변수 필터링 - 성능 더 안좋아짐

# %% [markdown]
# ## SelectKbest

# %%
from sklearn.feature_selection import SelectKBest, f_regression ,mutual_info_regression

x = data[x_col]
y = data[y_col]

selector = SelectKBest(score_func=mutual_info_regression, k='all')
selector.fit(x, y)

# 변수 중요도를 가져옵니다.
scores = selector.scores_

# 중요도를 내림차순으로 정렬합니다.
sorted_indices = np.argsort(scores)[::-1]
sorted_scores = scores[sorted_indices]

# 변수 중요도를 데이터프레임으로 확인합니다.
sorted_columns = np.array(x.columns.tolist())[sorted_indices]
variable_importance_df = pd.DataFrame({'변수': sorted_columns, '중요도': sorted_scores})

# Scree plot을 그립니다.
plt.figure(figsize=(10, 6))
plt.bar(range(len(sorted_scores)), sorted_scores)
plt.xticks(range(len(sorted_scores)), sorted_columns, rotation=90)  # x 축 레이블을 변수 이름으로 설정
plt.xlabel('변수')
plt.ylabel('변수 중요도')
plt.title('변수 중요도 Scree Plot')
plt.show()

# 변수 중요도를 출력합니다.
print(variable_importance_df)
# Out:
#                    변수       중요도
# 0     3_평균기온(°C)_mean  0.586277
# 1     2_평균기온(°C)_mean  0.512824
# 2      2_평균기온(°C)_min  0.453779
# 3     2_최고기온(°C)_mean  0.434827
# 4     2_최저기온(°C)_mean  0.392907
# 5     3_최저기온(°C)_mean  0.380892
# 6     3_최고기온(°C)_mean  0.367137
# 7      2_최저기온(°C)_min  0.365962
# 8      2_최고기온(°C)_min  0.324143
# 9                  위도  0.323187
# 10     3_평균기온(°C)_max  0.291138
# 11     3_최저기온(°C)_max  0.277338
# 12     3_평균기온(°C)_min  0.274166
# 13     3_최저기온(°C)_min  0.271507
# 14     2_평균기온(°C)_max  0.250266
# 15     2_최저기온(°C)_max  0.242740
# 16              서리365  0.226020
# 17                 고도  0.225649
# 18     3_최고기온(°C)_min  0.210577
# 19                 경도  0.196758
# 20     2_최고기온(°C)_max  0.194033
# 21     3_최고기온(°C)_max  0.102006
# 22     3_일강수량(mm)_sum  0.084369
# 23     2_일강수량(mm)_sum  0.061197
# 24  3_합계 일조시간(hr)_sum  0.027537
# 25  2_합계 일조시간(hr)_sum  0.024232

# %%
selected = variable_importance_df['변수'][0:16].tolist()

# %%
for model in models.keys():
  score = cv(x_data=data[selected],y_data=data[y_col],model=models[model])
  print(f'{model}: {score}')
# Out:
# rf: {'mae': 3.679718832891247, 'rmse': 5.127688822790712}
# xgbr: {'mae': 3.9087037751782163, 'rmse': 5.383210645599196}
# [LightGBM] [Info] Total Bins 2819
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 16
# [LightGBM] [Info] Start training from score 98.965517
# [LightGBM] [Info] Total Bins 2819
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 16
# [LightGBM] [Info] Start training from score 98.838859
# [LightGBM] [Info] Total Bins 2829
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 16
# [LightGBM] [Info] Start training from score 98.747347
# [LightGBM] [Info] Total Bins 2827
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 16
# [LightGBM] [Info] Start training from score 99.066313
# [LightGBM] [Info] Total Bins 2829
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 16
# [LightGBM] [Info] Start training from score 98.689655
# lgbm: {'mae': 3.7280921938208413, 'rmse': 5.181980607029351}
# svr: {'mae': 5.1994463378390146, 'rmse': 6.973078110534854}
# ard: {'mae': 3.8786700439622193, 'rmse': 5.28674318513942}
# bayesian_ridge: {'mae': 3.8842749867608077, 'rmse': 5.281520337180423}
# lasso: {'mae': 3.887350658009396, 'rmse': 5.282723135383916}
# cbr: {'mae': 3.608701957444193, 'rmse': 5.0058463238495055}
# etr: {'mae': 5.345888594164456, 'rmse': 7.336735265646074}
# mlp: {'mae': 4.292009445307156, 'rmse': 5.681697103549201}
# ada: {'mae': 4.287448453806883, 'rmse': 5.689824233832397}
# sgdr: {'mae': 3.911298216038297, 'rmse': 5.313662242325563}
# knn: {'mae': 4.27448275862069, 'rmse': 5.718409651949335}
# hgbr: {'mae': 3.764899704151413, 'rmse': 5.209615001185258}

# %% [markdown]
# ## 논문 기준 필터링 - 성능 더 안 좋아짐

# %% [markdown]
# *연구를 통해 2015년의 한반도 벚꽃개화시기를 확인해 본
# 결과, 2월의 평균기온, 3월의 최저 및 최고기온, 3월의 강수량, 3월의 일조량이 유의한 변수였다.*

# %%
paper = ['2_평균기온(°C)_mean',
         '3_최고기온(°C)_max',
         '3_최저기온(°C)_min',
         '3_일강수량(mm)_sum',
         '3_합계 일조시간(hr)_sum']

for model in models.keys():
  score = cv(x_data=data[paper],y_data=data[y_col],model=models[model])
  print(f'{model}: {score}')
# Out:
# rf: {'mae': 4.396206896551724, 'rmse': 5.929512150201892}
# xgbr: {'mae': 4.709725454315267, 'rmse': 6.368154161830712}
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 1029
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 5
# [LightGBM] [Info] Start training from score 98.965517
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 1027
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 5
# [LightGBM] [Info] Start training from score 98.838859
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 1024
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 5
# [LightGBM] [Info] Start training from score 98.747347
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 1026
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 5
# [LightGBM] [Info] Start training from score 99.066313
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 1023
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 5
# [LightGBM] [Info] Start training from score 98.689655
# lgbm: {'mae': 4.527755790267075, 'rmse': 6.04208050552406}
# svr: {'mae': 7.219097571080448, 'rmse': 9.284290016201881}
# ard: {'mae': 4.507493712896976, 'rmse': 6.007978687262246}
# bayesian_ridge: {'mae': 4.492426672850694, 'rmse': 6.001689072481822}
# lasso: {'mae': 4.493215096834854, 'rmse': 6.001618315009161}
# cbr: {'mae': 4.31076090439089, 'rmse': 5.806275207776598}
# etr: {'mae': 6.187267904509285, 'rmse': 8.301562087850957}
# mlp: {'mae': 4.994895168976282, 'rmse': 6.799284729139217}
# ada: {'mae': 4.902222623001917, 'rmse': 6.484365729617752}
# sgdr: {'mae': 4.488691171974495, 'rmse': 5.999263309839889}
# knn: {'mae': 6.026419098143236, 'rmse': 7.824233956187842}
# hgbr: {'mae': 4.5375077155590535, 'rmse': 6.060316814604171}

# %% [markdown]
# # PCA 차원축소 - 성능 더 안 좋아짐 !

# %%
numeric = ['2_일강수량(mm)_sum',
 '3_일강수량(mm)_sum',
 '2_최고기온(°C)_max',
 '3_최고기온(°C)_max',
 '2_최고기온(°C)_mean',
 '3_최고기온(°C)_mean',
 '2_최고기온(°C)_min',
 '3_최고기온(°C)_min',
 '2_최저기온(°C)_max',
 '3_최저기온(°C)_max',
 '2_최저기온(°C)_mean',
 '3_최저기온(°C)_mean',
 '2_최저기온(°C)_min',
 '3_최저기온(°C)_min',
 '2_평균기온(°C)_max',
 '3_평균기온(°C)_max',
 '2_평균기온(°C)_mean',
 '3_평균기온(°C)_mean',
 '2_평균기온(°C)_min',
 '3_평균기온(°C)_min',
 '2_합계 일조시간(hr)_sum',
 '3_합계 일조시간(hr)_sum']

num_scaled = StandardScaler().fit_transform(data[numeric])

pca = PCA(n_components=7)  # 주성분을 몇개로 할지 결정
printcipalComponents = pca.fit_transform(num_scaled)
principalDf = pd.DataFrame(data=printcipalComponents)

# %%
pd.DataFrame(pca.explained_variance_ratio_).cumsum().transpose()
# Out:
#           0        1         2         3         4         5         6
# 0  0.508154  0.61217  0.693872  0.753816  0.807313  0.855033  0.889776

# %%
for model in models.keys():
  score = cv(x_data=principalDf,y_data=data[y_col],model=models[model],metric='mae')
  print(f'{model}: {score}')
# Out:
# rf: 4.008116710875331
# xgbr: 4.275591972209415
# [LightGBM] [Info] Total Bins 1785
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 7
# [LightGBM] [Info] Start training from score 98.965517
# [LightGBM] [Info] Total Bins 1785
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 7
# [LightGBM] [Info] Start training from score 98.838859
# [LightGBM] [Info] Total Bins 1785
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 7
# [LightGBM] [Info] Start training from score 98.747347
# [LightGBM] [Info] Total Bins 1785
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 7
# [LightGBM] [Info] Start training from score 99.066313
# [LightGBM] [Info] Total Bins 1785
# [LightGBM] [Info] Number of data points in the train set: 1508, number of used features: 7
# [LightGBM] [Info] Start training from score 98.689655
# lgbm: 4.1156596063287125
# svr: 4.149093523842341
# ard: 4.098167768789371
# bayesian_ridge: 4.103134180944061
# lasso: 4.103999096191337
# cbr: 3.927430788904573
# etr: 5.781962864721486
# mlp: 4.103564503794589
# ada: 4.582894385730514
# sgdr: 4.107630335466871
# knn: 4.0801061007957555
# hgbr: 4.056007881573657
# ols: 4.103999096191337

# %% [markdown]
# # 하이퍼 파라미터 튜닝

# %%
def rf_objective(trial):

  rf_param = {
          'n_estimators': trial.suggest_int('n_estimators', 80, 700),
          'criterion': 'absolute_error',
          'max_depth' : trial.suggest_int('max_depth', 3, 10),
          'min_samples_split': trial.suggest_int('min_samples_split', 3, 10),
          'min_samples_leaf': trial.suggest_int('min_samples_leaf', 3, 10),
          'min_weight_fraction_leaf': 0.0,
          'max_features': trial.suggest_float('max_features', 0.1, 1.0),
          'max_leaf_nodes': None,
          'min_impurity_decrease': 0.0,
          'bootstrap': True,
          'n_jobs': -1,  # 모든 가능한 CPU 코어 사용 (-1)
          'random_state': 28
      }

  rf= RandomForestRegressor(**rf_param)

  score = cv(x_data=data[x_col],y_data=data[y_col],model=rf,metric='mae')

  return score

def lgbm_objective(trial):



  lgbm_param = { 'objective': 'regression', # 회귀
          'verbose': -1,
          'metric': 'rmse',
          'max_depth': trial.suggest_int('max_depth',3, 15),
          'learning_rate': trial.suggest_loguniform("learning_rate", 1e-8, 1e-2),
          'n_estimators': trial.suggest_int('n_estimators', 100, 3000),
          'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
          'subsample': trial.suggest_loguniform('subsample', 0.4, 1),
      }

  lgbm = lgb.LGBMRegressor(**lgbm_param)

  score = cv(x_data=data[x_col],y_data=data[y_col],model=lgbm,metric='mae')

  return score

def cbrm_objective(trial):

  cbrm_param = {
        'iterations': trial.suggest_int('iterations', 1000, 20000),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1.0),
        'depth': trial.suggest_int('depth', 1, 15),
        'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 100),
        'random_strength': trial.suggest_uniform('random_strength', 0, 1),
        'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.01, 100.0),
        'border_count': trial.suggest_int('border_count', 1, 255),
        'thread_count': 4,
        'verbose': False }

  cbrm = CatBoostRegressor(**cbrm_param)

  score = cv(x_data=data[x_col],y_data=data[y_col],model=cbrm,metric='mae')
  return score

# %% [markdown]
# ## 랜덤포레스트

# %%
rf_study = optuna.create_study(direction='minimize', sampler=TPESampler())
rf_study.optimize(rf_objective,n_trials=100,timeout= 3600)
# Out:
# [I 2023-09-29 07:30:02,949] A new study created in memory with name: no-name-6a8a303f-4791-42d9-a4af-2b4c209a7697
# [I 2023-09-29 07:33:51,584] Trial 0 finished with value: 3.70377414099599 and parameters: {'n_estimators': 562, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 0.6155982018362203}. Best is trial 0 with value: 3.70377414099599.
# [I 2023-09-29 07:35:51,242] Trial 1 finished with value: 3.691175413882643 and parameters: {'n_estimators': 267, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 0.7252144053391465}. Best is trial 1 with value: 3.691175413882643.
# [I 2023-09-29 07:36:49,927] Trial 2 finished with value: 3.8969569433626043 and parameters: {'n_estimators': 520, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 0.2118573881228118}. Best is trial 1 with value: 3.691175413882643.
# [I 2023-09-29 07:37:15,331] Trial 3 finished with value: 3.7215823364725447 and parameters: {'n_estimators': 232, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': 0.15739115067363507}. Best is trial 1 with value: 3.691175413882643.
# [I 2023-09-29 07:41:58,468] Trial 4 finished with value: 3.772024463929526 and parameters: {'n_estimators': 599, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 0.8678465918427251}. Best is trial 1 with value: 3.691175413882643.
# [I 2023-09-29 07:45:23,556] Trial 5 finished with value: 3.746119180114875 and parameters: {'n_estimators': 412, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 0.861283476149105}. Best is trial 1 with value: 3.691175413882643.
# [I 2023-09-29 07:46:50,772] Trial 6 finished with value: 3.6686654406628385 and parameters: {'n_estimators': 377, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 0.35116914392232124}. Best is trial 6 with value: 3.6686654406628385.
# [I 2023-09-29 07:48:28,768] Trial 7 finished with value: 3.9680785488017407 and parameters: {'n_estimators': 401, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 0.5488210493582648}. Best is trial 6 with value: 3.6686654406628385.
# [I 2023-09-29 07:50:45,950] Trial 8 finished with value: 3.704648779777081 and parameters: {'n_estimators': 400, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 0.5966501362570564}. Best is trial 6 with value: 3.6686654406628385.
# [I 2023-09-29 07:54:31,003] Trial 9 finished with value: 3.7240419651457386 and parameters: {'n_estimators': 540, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 0.6924723993322149}. Best is trial 6 with value: 3.6686654406628385.
# [I 2023-09-29 07:54:58,209] Trial 10 finished with value: 3.7549897959916563 and parameters: {'n_estimators': 142, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 0.3447420334731731}. Best is trial 6 with value: 3.6686654406628385.
# [I 2023-09-29 07:56:14,331] Trial 11 finished with value: 3.6438211340254183 and parameters: {'n_estimators': 266, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.3882773228365112}. Best is trial 11 with value: 3.6438211340254183.
# [I 2023-09-29 07:57:32,631] Trial 12 finished with value: 3.6423672914591068 and parameters: {'n_estimators': 284, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.408060158260025}. Best is trial 12 with value: 3.6423672914591068.
# [I 2023-09-29 07:58:42,320] Trial 13 finished with value: 3.6438456842961555 and parameters: {'n_estimators': 240, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.42056199536048766}. Best is trial 12 with value: 3.6423672914591068.
# [I 2023-09-29 07:59:15,206] Trial 14 finished with value: 3.6653699652883747 and parameters: {'n_estimators': 111, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.4433688484575196}. Best is trial 12 with value: 3.6423672914591068.
# [I 2023-09-29 08:00:07,992] Trial 15 finished with value: 3.6624557657210337 and parameters: {'n_estimators': 304, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 0.2643627318091757}. Best is trial 12 with value: 3.6423672914591068.
# [I 2023-09-29 08:00:26,765] Trial 16 finished with value: 3.693957924536136 and parameters: {'n_estimators': 186, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.117260656459091}. Best is trial 12 with value: 3.6423672914591068.
# [I 2023-09-29 08:02:05,676] Trial 17 finished with value: 3.667459475336834 and parameters: {'n_estimators': 312, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 0.489022040262797}. Best is trial 12 with value: 3.6423672914591068.
# [I 2023-09-29 08:04:08,252] Trial 18 finished with value: 3.707580173030569 and parameters: {'n_estimators': 682, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 0.2883169558202179}. Best is trial 12 with value: 3.6423672914591068.
# [I 2023-09-29 08:04:29,973] Trial 19 finished with value: 3.651942760370433 and parameters: {'n_estimators': 81, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 0.38749395318846896}. Best is trial 12 with value: 3.6423672914591068.
# [I 2023-09-29 08:06:59,519] Trial 20 finished with value: 3.6662410306414417 and parameters: {'n_estimators': 478, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 0.4873852421515954}. Best is trial 12 with value: 3.6423672914591068.
# [I 2023-09-29 08:08:00,187] Trial 21 finished with value: 3.643052572132123 and parameters: {'n_estimators': 222, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.40089991907633316}. Best is trial 12 with value: 3.6423672914591068.
# [I 2023-09-29 08:08:40,975] Trial 22 finished with value: 3.6334412994790357 and parameters: {'n_estimators': 195, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.3057079408648393}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:09:12,902] Trial 23 finished with value: 3.655837593837139 and parameters: {'n_estimators': 166, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 0.2670017122956555}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:10:01,231] Trial 24 finished with value: 3.6399381118109924 and parameters: {'n_estimators': 217, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.3276831709639186}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:10:53,432] Trial 25 finished with value: 3.6401486609377876 and parameters: {'n_estimators': 329, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.2016262621095674}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:11:45,244] Trial 26 finished with value: 3.6522176909971718 and parameters: {'n_estimators': 352, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 0.1966981309623636}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:12:03,373] Trial 27 finished with value: 3.7461097324886965 and parameters: {'n_estimators': 188, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.12141205737368758}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:12:53,896] Trial 28 finished with value: 3.6797555397740602 and parameters: {'n_estimators': 326, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': 0.2149957786905083}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:14:34,122] Trial 29 finished with value: 3.6409018128521913 and parameters: {'n_estimators': 454, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 0.3199945410893412}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:14:57,325] Trial 30 finished with value: 3.663015421799043 and parameters: {'n_estimators': 141, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 0.259354639114356}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:16:41,119] Trial 31 finished with value: 3.6410999674180267 and parameters: {'n_estimators': 455, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 0.31985360403230384}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:18:24,830] Trial 32 finished with value: 3.6441611360875874 and parameters: {'n_estimators': 471, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': 0.31413517082155856}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:19:19,461] Trial 33 finished with value: 3.6414078349877754 and parameters: {'n_estimators': 342, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.2002334369623669}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:19:45,521] Trial 34 finished with value: 3.6765209489355093 and parameters: {'n_estimators': 212, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': 0.1573677066097251}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:21:05,390] Trial 35 finished with value: 3.6402860750780164 and parameters: {'n_estimators': 443, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 0.23359985365490454}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:21:24,772] Trial 36 finished with value: 3.767006296084839 and parameters: {'n_estimators': 258, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 0.10019847324567199}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:22:53,908] Trial 37 finished with value: 3.778558470803007 and parameters: {'n_estimators': 606, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': 0.2412746464873548}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:23:47,491] Trial 38 finished with value: 3.6756828983387875 and parameters: {'n_estimators': 433, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 0.1579586186013648}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:24:46,704] Trial 39 finished with value: 4.023659856152195 and parameters: {'n_estimators': 511, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.23755594323360538}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:26:05,776] Trial 40 finished with value: 3.63874407524181 and parameters: {'n_estimators': 379, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.28573522395302536}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:27:21,939] Trial 41 finished with value: 3.63874407524181 and parameters: {'n_estimators': 379, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.2883624237469903}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:28:46,313] Trial 42 finished with value: 3.6455983271650196 and parameters: {'n_estimators': 346, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 0.34641562542070137}. Best is trial 22 with value: 3.6334412994790357.
# [I 2023-09-29 08:30:04,100] Trial 43 finished with value: 3.639479884125675 and parameters: {'n_estimators': 379, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 0.301937421133569}. Best is trial 22 with value: 3.6334412994790357.

# %%
trial = rf_study.best_trial
trial_params = trial.params
print('Best Trial: score {},\nparams {}'.format(trial.value, trial_params))
# Out:
# Best Trial: score 3.6334412994790357,
# params {'n_estimators': 195, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.3057079408648393}

# %% [markdown]
# ## LigthGBM

# %%
lgbm_study = optuna.create_study(direction='minimize', sampler=TPESampler())
lgbm_study.optimize(lgbm_objective,n_trials=100,timeout = 1800)
# Out:
# [I 2023-09-29 07:02:10,125] A new study created in memory with name: no-name-61bb8df3-cb7b-4c5d-814d-794f8d2b0693
# [I 2023-09-29 07:02:29,676] Trial 0 finished with value: 7.089025352175208 and parameters: {'max_depth': 5, 'learning_rate': 5.2300047661717494e-08, 'n_estimators': 2436, 'min_child_samples': 31, 'subsample': 0.4655600521395932}. Best is trial 0 with value: 7.089025352175208.
# [I 2023-09-29 07:02:30,889] Trial 1 finished with value: 7.087035023305058 and parameters: {'max_depth': 5, 'learning_rate': 1.7590426774469504e-06, 'n_estimators': 311, 'min_child_samples': 82, 'subsample': 0.5306435674169581}. Best is trial 1 with value: 7.087035023305058.
# [I 2023-09-29 07:02:37,217] Trial 2 finished with value: 4.0237942162757765 and parameters: {'max_depth': 10, 'learning_rate': 0.0021820804811331033, 'n_estimators': 634, 'min_child_samples': 48, 'subsample': 0.7581442595758341}. Best is trial 2 with value: 4.0237942162757765.
# [I 2023-09-29 07:02:54,046] Trial 3 finished with value: 7.089493062625787 and parameters: {'max_depth': 5, 'learning_rate': 1.2783995352704568e-08, 'n_estimators': 2230, 'min_child_samples': 27, 'subsample': 0.5384364493325103}. Best is trial 2 with value: 4.0237942162757765.
# [I 2023-09-29 07:03:11,425] Trial 4 finished with value: 6.23464161833442 and parameters: {'max_depth': 12, 'learning_rate': 0.00013729668439070147, 'n_estimators': 1438, 'min_child_samples': 20, 'subsample': 0.521363912450646}. Best is trial 2 with value: 4.0237942162757765.
# [I 2023-09-29 07:03:22,214] Trial 5 finished with value: 7.083278846262904 and parameters: {'max_depth': 5, 'learning_rate': 5.865525251126059e-07, 'n_estimators': 2284, 'min_child_samples': 83, 'subsample': 0.5614474621184405}. Best is trial 2 with value: 4.0237942162757765.
# [I 2023-09-29 07:03:26,950] Trial 6 finished with value: 7.086508561457518 and parameters: {'max_depth': 4, 'learning_rate': 5.575425904426121e-07, 'n_estimators': 1186, 'min_child_samples': 54, 'subsample': 0.8130770787498648}. Best is trial 2 with value: 4.0237942162757765.
# [I 2023-09-29 07:03:38,905] Trial 7 finished with value: 5.164357405292103 and parameters: {'max_depth': 8, 'learning_rate': 0.0002820537639512606, 'n_estimators': 2003, 'min_child_samples': 65, 'subsample': 0.8814460961055628}. Best is trial 2 with value: 4.0237942162757765.
# [I 2023-09-29 07:03:42,951] Trial 8 finished with value: 7.088276432542267 and parameters: {'max_depth': 4, 'learning_rate': 2.6592807592868396e-07, 'n_estimators': 1082, 'min_child_samples': 72, 'subsample': 0.43300529400614607}. Best is trial 2 with value: 4.0237942162757765.
# [I 2023-09-29 07:03:50,524] Trial 9 finished with value: 7.089601691017272 and parameters: {'max_depth': 7, 'learning_rate': 1.0657301662811628e-08, 'n_estimators': 536, 'min_child_samples': 16, 'subsample': 0.6024344138498304}. Best is trial 2 with value: 4.0237942162757765.
# [I 2023-09-29 07:03:53,991] Trial 10 finished with value: 3.59898053923189 and parameters: {'max_depth': 15, 'learning_rate': 0.0057944371931102105, 'n_estimators': 802, 'min_child_samples': 98, 'subsample': 0.7230470733289777}. Best is trial 10 with value: 3.59898053923189.
# [I 2023-09-29 07:04:01,198] Trial 11 finished with value: 3.4956053340922275 and parameters: {'max_depth': 15, 'learning_rate': 0.008513441173672833, 'n_estimators': 728, 'min_child_samples': 45, 'subsample': 0.722977587776388}. Best is trial 11 with value: 3.4956053340922275.
# [I 2023-09-29 07:04:06,225] Trial 12 finished with value: 3.5388737111925286 and parameters: {'max_depth': 15, 'learning_rate': 0.008589933401171807, 'n_estimators': 865, 'min_child_samples': 100, 'subsample': 0.7168391262393836}. Best is trial 11 with value: 3.4956053340922275.
# [I 2023-09-29 07:04:21,504] Trial 13 finished with value: 3.491724830901016 and parameters: {'max_depth': 15, 'learning_rate': 0.007385263510287688, 'n_estimators': 1714, 'min_child_samples': 42, 'subsample': 0.6689701644481334}. Best is trial 13 with value: 3.491724830901016.
# [I 2023-09-29 07:04:36,766] Trial 14 finished with value: 3.7467013006104386 and parameters: {'max_depth': 13, 'learning_rate': 0.001106427443254782, 'n_estimators': 1777, 'min_child_samples': 42, 'subsample': 0.6603874680293321}. Best is trial 13 with value: 3.491724830901016.
# [I 2023-09-29 07:05:14,415] Trial 15 finished with value: 6.580820866370385 and parameters: {'max_depth': 13, 'learning_rate': 4.177500292666775e-05, 'n_estimators': 2701, 'min_child_samples': 5, 'subsample': 0.9894971858628627}. Best is trial 13 with value: 3.491724830901016.
# [I 2023-09-29 07:05:15,989] Trial 16 finished with value: 6.487312105101073 and parameters: {'max_depth': 11, 'learning_rate': 0.0008935027930959237, 'n_estimators': 150, 'min_child_samples': 38, 'subsample': 0.6434814849090793}. Best is trial 13 with value: 3.491724830901016.
# [I 2023-09-29 07:05:27,034] Trial 17 finished with value: 3.4979573594253823 and parameters: {'max_depth': 14, 'learning_rate': 0.009697058647841258, 'n_estimators': 1544, 'min_child_samples': 58, 'subsample': 0.675344827318176}. Best is trial 13 with value: 3.491724830901016.
# [I 2023-09-29 07:05:51,313] Trial 18 finished with value: 6.920643622362751 and parameters: {'max_depth': 10, 'learning_rate': 1.2313074450041576e-05, 'n_estimators': 2886, 'min_child_samples': 42, 'subsample': 0.6150226037443146}. Best is trial 13 with value: 3.491724830901016.
# [I 2023-09-29 07:05:57,889] Trial 19 finished with value: 5.556218583157175 and parameters: {'max_depth': 13, 'learning_rate': 0.0003217495606981471, 'n_estimators': 1263, 'min_child_samples': 62, 'subsample': 0.79878319669868}. Best is trial 13 with value: 3.491724830901016.
# [I 2023-09-29 07:06:12,504] Trial 20 finished with value: 3.5074295513236855 and parameters: {'max_depth': 15, 'learning_rate': 0.0024389047093506446, 'n_estimators': 1855, 'min_child_samples': 49, 'subsample': 0.7112381887595789}. Best is trial 13 with value: 3.491724830901016.
# [I 2023-09-29 07:06:24,420] Trial 21 finished with value: 3.498385254510724 and parameters: {'max_depth': 14, 'learning_rate': 0.007831572231675079, 'n_estimators': 1617, 'min_child_samples': 58, 'subsample': 0.675184205810317}. Best is trial 13 with value: 3.491724830901016.
# [I 2023-09-29 07:06:34,284] Trial 22 finished with value: 3.564326302861916 and parameters: {'max_depth': 14, 'learning_rate': 0.0025653879236661003, 'n_estimators': 1546, 'min_child_samples': 69, 'subsample': 0.6012663832604963}. Best is trial 13 with value: 3.491724830901016.
# [I 2023-09-29 07:06:41,930] Trial 23 finished with value: 3.4664585891590414 and parameters: {'max_depth': 12, 'learning_rate': 0.00910508774914054, 'n_estimators': 991, 'min_child_samples': 37, 'subsample': 0.6433832656458656}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:06:52,129] Trial 24 finished with value: 4.7732151991157945 and parameters: {'max_depth': 12, 'learning_rate': 0.0007928753281495392, 'n_estimators': 917, 'min_child_samples': 33, 'subsample': 0.6330625489020585}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:06:57,848] Trial 25 finished with value: 3.7948818711836716 and parameters: {'max_depth': 12, 'learning_rate': 0.00313727834711836, 'n_estimators': 559, 'min_child_samples': 24, 'subsample': 0.7672624877684563}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:07:11,060] Trial 26 finished with value: 4.837039277640759 and parameters: {'max_depth': 11, 'learning_rate': 0.000519454702494856, 'n_estimators': 1334, 'min_child_samples': 36, 'subsample': 0.5808578777547844}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:07:20,541] Trial 27 finished with value: 6.300156452932066 and parameters: {'max_depth': 15, 'learning_rate': 0.00016907538321427558, 'n_estimators': 1072, 'min_child_samples': 50, 'subsample': 0.6793992886373704}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:07:26,675] Trial 28 finished with value: 4.978159702494491 and parameters: {'max_depth': 14, 'learning_rate': 0.0015833229274306686, 'n_estimators': 396, 'min_child_samples': 9, 'subsample': 0.6361383696855742}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:07:41,497] Trial 29 finished with value: 3.4875922285259193 and parameters: {'max_depth': 9, 'learning_rate': 0.004114679601116257, 'n_estimators': 2023, 'min_child_samples': 41, 'subsample': 0.4850855806696209}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:07:57,384] Trial 30 finished with value: 3.4924861828105818 and parameters: {'max_depth': 8, 'learning_rate': 0.00396559297564144, 'n_estimators': 2090, 'min_child_samples': 30, 'subsample': 0.48447271751587867}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:08:12,298] Trial 31 finished with value: 3.5012151882696108 and parameters: {'max_depth': 7, 'learning_rate': 0.004045613390936545, 'n_estimators': 2163, 'min_child_samples': 30, 'subsample': 0.48856646537684256}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:08:29,884] Trial 32 finished with value: 3.613761729907947 and parameters: {'max_depth': 9, 'learning_rate': 0.0013364056709110133, 'n_estimators': 1934, 'min_child_samples': 38, 'subsample': 0.40180717447199443}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:08:53,280] Trial 33 finished with value: 3.5181714376092286 and parameters: {'max_depth': 8, 'learning_rate': 0.0029360980265370033, 'n_estimators': 2469, 'min_child_samples': 18, 'subsample': 0.4835690909636639}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:09:14,778] Trial 34 finished with value: 3.5221818679902532 and parameters: {'max_depth': 9, 'learning_rate': 0.0031751057516893858, 'n_estimators': 2532, 'min_child_samples': 25, 'subsample': 0.5175505927188234}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:09:37,746] Trial 35 finished with value: 4.0100245057906765 and parameters: {'max_depth': 10, 'learning_rate': 0.0006468994617232884, 'n_estimators': 2110, 'min_child_samples': 32, 'subsample': 0.5583877532366999}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:09:45,878] Trial 36 finished with value: 3.5158956383369344 and parameters: {'max_depth': 6, 'learning_rate': 0.005021594183218162, 'n_estimators': 1732, 'min_child_samples': 43, 'subsample': 0.4419556258978845}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:10:09,500] Trial 37 finished with value: 3.514588975576512 and parameters: {'max_depth': 8, 'learning_rate': 0.001760496200700023, 'n_estimators': 2283, 'min_child_samples': 28, 'subsample': 0.536069039447684}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:10:23,475] Trial 38 finished with value: 6.426607343338998 and parameters: {'max_depth': 10, 'learning_rate': 7.322209964065583e-05, 'n_estimators': 2042, 'min_child_samples': 54, 'subsample': 0.513057091794975}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:10:47,307] Trial 39 finished with value: 4.617397201887471 and parameters: {'max_depth': 11, 'learning_rate': 0.000482724876474268, 'n_estimators': 1704, 'min_child_samples': 13, 'subsample': 0.5668129127813724}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:10:52,315] Trial 40 finished with value: 3.6066086033191844 and parameters: {'max_depth': 3, 'learning_rate': 0.004679412843015956, 'n_estimators': 1388, 'min_child_samples': 22, 'subsample': 0.4965928308160517}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:11:04,726] Trial 41 finished with value: 3.517975727391309 and parameters: {'max_depth': 7, 'learning_rate': 0.006886750627743922, 'n_estimators': 2324, 'min_child_samples': 44, 'subsample': 0.46528239162407126}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:11:09,660] Trial 42 finished with value: 3.508713670258301 and parameters: {'max_depth': 9, 'learning_rate': 0.009633288735195315, 'n_estimators': 703, 'min_child_samples': 46, 'subsample': 0.6100091110554103}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:11:20,953] Trial 43 finished with value: 3.7807342988920873 and parameters: {'max_depth': 13, 'learning_rate': 0.001686984161913944, 'n_estimators': 1072, 'min_child_samples': 36, 'subsample': 0.5804404589486698}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:11:29,802] Trial 44 finished with value: 3.5187902352082006 and parameters: {'max_depth': 6, 'learning_rate': 0.005114334019991425, 'n_estimators': 1856, 'min_child_samples': 39, 'subsample': 0.5425401184878055}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:11:34,028] Trial 45 finished with value: 4.986170948896567 and parameters: {'max_depth': 8, 'learning_rate': 0.001407797746843735, 'n_estimators': 446, 'min_child_samples': 47, 'subsample': 0.709220895472716}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:11:39,319] Trial 46 finished with value: 3.5765941298167254 and parameters: {'max_depth': 15, 'learning_rate': 0.004438728853560072, 'n_estimators': 730, 'min_child_samples': 53, 'subsample': 0.6528937319953361}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:11:41,102] Trial 47 finished with value: 6.359386839699569 and parameters: {'max_depth': 11, 'learning_rate': 0.0008381617148861798, 'n_estimators': 199, 'min_child_samples': 33, 'subsample': 0.7595693440862507}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:11:53,939] Trial 48 finished with value: 3.5263557727781425 and parameters: {'max_depth': 12, 'learning_rate': 0.0025423130853211217, 'n_estimators': 2644, 'min_child_samples': 91, 'subsample': 0.6976809803223117}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:12:08,962] Trial 49 finished with value: 3.4936905230618827 and parameters: {'max_depth': 14, 'learning_rate': 0.008383437661414061, 'n_estimators': 1476, 'min_child_samples': 27, 'subsample': 0.739095426608895}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:12:23,656] Trial 50 finished with value: 3.477112472080022 and parameters: {'max_depth': 14, 'learning_rate': 0.009490516120246107, 'n_estimators': 1475, 'min_child_samples': 29, 'subsample': 0.6159115884854198}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:12:38,916] Trial 51 finished with value: 3.5017719374624248 and parameters: {'max_depth': 14, 'learning_rate': 0.009857080578673372, 'n_estimators': 1486, 'min_child_samples': 25, 'subsample': 0.6111174712347556}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:12:57,470] Trial 52 finished with value: 3.4755864284629654 and parameters: {'max_depth': 13, 'learning_rate': 0.004894871002672445, 'n_estimators': 1646, 'min_child_samples': 13, 'subsample': 0.6451268478985425}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:13:14,887] Trial 53 finished with value: 3.4938421358485714 and parameters: {'max_depth': 13, 'learning_rate': 0.00456694312176983, 'n_estimators': 1650, 'min_child_samples': 21, 'subsample': 0.656815118873021}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:13:40,659] Trial 54 finished with value: 3.6408878627179844 and parameters: {'max_depth': 13, 'learning_rate': 0.0012052493567424548, 'n_estimators': 1946, 'min_child_samples': 12, 'subsample': 0.629761867480946}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:13:52,279] Trial 55 finished with value: 3.559332036120882 and parameters: {'max_depth': 12, 'learning_rate': 0.0025063867652344897, 'n_estimators': 1212, 'min_child_samples': 40, 'subsample': 0.5894138354016001}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:14:14,207] Trial 56 finished with value: 3.49585985402591 and parameters: {'max_depth': 15, 'learning_rate': 0.005884494035666949, 'n_estimators': 1792, 'min_child_samples': 17, 'subsample': 0.6230740519435675}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:14:37,105] Trial 57 finished with value: 3.49304390582918 and parameters: {'max_depth': 14, 'learning_rate': 0.0019336568791063764, 'n_estimators': 2060, 'min_child_samples': 29, 'subsample': 0.6933184139432464}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:15:09,250] Trial 58 finished with value: 3.5042053727920406 and parameters: {'max_depth': 7, 'learning_rate': 0.0035786343479525377, 'n_estimators': 1594, 'min_child_samples': 6, 'subsample': 0.649355223616622}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:15:31,795] Trial 59 finished with value: 3.64064786991758 and parameters: {'max_depth': 9, 'learning_rate': 0.0010069497518759437, 'n_estimators': 2364, 'min_child_samples': 35, 'subsample': 0.54797066680087}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:15:46,382] Trial 60 finished with value: 4.676886426917858 and parameters: {'max_depth': 10, 'learning_rate': 0.0003625992176947281, 'n_estimators': 2217, 'min_child_samples': 57, 'subsample': 0.5654260623110803}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:16:09,994] Trial 61 finished with value: 3.5191190135767885 and parameters: {'max_depth': 14, 'learning_rate': 0.0018069637639302897, 'n_estimators': 2107, 'min_child_samples': 31, 'subsample': 0.6738199734882411}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:16:29,120] Trial 62 finished with value: 3.48139364742404 and parameters: {'max_depth': 13, 'learning_rate': 0.006532570579933431, 'n_estimators': 2025, 'min_child_samples': 28, 'subsample': 0.6914918785384854}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:16:45,141] Trial 63 finished with value: 3.499202341287112 and parameters: {'max_depth': 12, 'learning_rate': 0.006067398326022535, 'n_estimators': 1961, 'min_child_samples': 41, 'subsample': 0.6410067796694509}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:17:02,317] Trial 64 finished with value: 3.524168288628272 and parameters: {'max_depth': 13, 'learning_rate': 0.009770748061435984, 'n_estimators': 1891, 'min_child_samples': 35, 'subsample': 0.7320254633657106}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:17:26,046] Trial 65 finished with value: 3.4751673506942895 and parameters: {'max_depth': 15, 'learning_rate': 0.0035749268776013054, 'n_estimators': 1785, 'min_child_samples': 14, 'subsample': 0.6852847717589957}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:17:47,904] Trial 66 finished with value: 3.490435766917799 and parameters: {'max_depth': 15, 'learning_rate': 0.006785136078108373, 'n_estimators': 1782, 'min_child_samples': 13, 'subsample': 0.6717308144933484}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:18:00,269] Trial 67 finished with value: 3.560783896350096 and parameters: {'max_depth': 15, 'learning_rate': 0.0033061731163061252, 'n_estimators': 965, 'min_child_samples': 14, 'subsample': 0.690617084258672}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:18:25,316] Trial 68 finished with value: 3.5041549650689796 and parameters: {'max_depth': 15, 'learning_rate': 0.006488272949687748, 'n_estimators': 1797, 'min_child_samples': 9, 'subsample': 0.6581297154650051}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:18:41,157] Trial 69 finished with value: 3.565971508001719 and parameters: {'max_depth': 13, 'learning_rate': 0.002341450027052695, 'n_estimators': 1334, 'min_child_samples': 19, 'subsample': 0.5992258728149708}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:19:03,083] Trial 70 finished with value: 3.856146298338858 and parameters: {'max_depth': 14, 'learning_rate': 0.0009914816866643293, 'n_estimators': 1685, 'min_child_samples': 9, 'subsample': 0.6297876081924111}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:19:22,584] Trial 71 finished with value: 3.4898844851461646 and parameters: {'max_depth': 15, 'learning_rate': 0.006132675537428129, 'n_estimators': 1564, 'min_child_samples': 16, 'subsample': 0.6753094774142565}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:19:40,880] Trial 72 finished with value: 3.4875164877969085 and parameters: {'max_depth': 15, 'learning_rate': 0.006125967440197658, 'n_estimators': 1570, 'min_child_samples': 16, 'subsample': 0.674902418570786}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:19:58,588] Trial 73 finished with value: 3.489417903204324 and parameters: {'max_depth': 14, 'learning_rate': 0.003995786135846139, 'n_estimators': 1514, 'min_child_samples': 15, 'subsample': 0.6871687593669336}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:20:14,691] Trial 74 finished with value: 3.48980802265599 and parameters: {'max_depth': 14, 'learning_rate': 0.003589206777495507, 'n_estimators': 1400, 'min_child_samples': 22, 'subsample': 0.7020788420556544}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:20:32,417] Trial 75 finished with value: 3.6015423809687364 and parameters: {'max_depth': 13, 'learning_rate': 0.0021047238593120627, 'n_estimators': 1299, 'min_child_samples': 5, 'subsample': 0.7190307406681667}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:20:46,261] Trial 76 finished with value: 3.5085567172882697 and parameters: {'max_depth': 14, 'learning_rate': 0.003711185605943061, 'n_estimators': 1176, 'min_child_samples': 23, 'subsample': 0.6434631462576438}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:21:09,129] Trial 77 finished with value: 4.260644206512827 and parameters: {'max_depth': 14, 'learning_rate': 0.0006660692234030257, 'n_estimators': 1634, 'min_child_samples': 19, 'subsample': 0.7439420065460641}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:21:29,134] Trial 78 finished with value: 3.665734431004541 and parameters: {'max_depth': 12, 'learning_rate': 0.0015181321853391275, 'n_estimators': 1489, 'min_child_samples': 11, 'subsample': 0.6223002434935914}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:21:52,192] Trial 79 finished with value: 3.4823947801644364 and parameters: {'max_depth': 13, 'learning_rate': 0.005069277102903367, 'n_estimators': 2196, 'min_child_samples': 16, 'subsample': 0.6626909005852177}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:22:12,605] Trial 80 finished with value: 3.5210599602000654 and parameters: {'max_depth': 13, 'learning_rate': 0.009915925517659178, 'n_estimators': 2016, 'min_child_samples': 25, 'subsample': 0.6646986922220841}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:22:35,877] Trial 81 finished with value: 3.4895831181450467 and parameters: {'max_depth': 14, 'learning_rate': 0.0049215744413941345, 'n_estimators': 2203, 'min_child_samples': 16, 'subsample': 0.6856640825359335}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:22:59,604] Trial 82 finished with value: 3.498125140221738 and parameters: {'max_depth': 13, 'learning_rate': 0.0028289841540571877, 'n_estimators': 1907, 'min_child_samples': 15, 'subsample': 0.7071620189862216}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:23:19,613] Trial 83 finished with value: 3.499805576853016 and parameters: {'max_depth': 15, 'learning_rate': 0.006773072889495849, 'n_estimators': 1711, 'min_child_samples': 7, 'subsample': 0.6877157396323663}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:23:45,775] Trial 84 finished with value: 3.503252249123308 and parameters: {'max_depth': 12, 'learning_rate': 0.0038834675920958843, 'n_estimators': 2436, 'min_child_samples': 20, 'subsample': 0.6529887959731585}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:24:09,926] Trial 85 finished with value: 3.51306350618545 and parameters: {'max_depth': 14, 'learning_rate': 0.002310491303393484, 'n_estimators': 1853, 'min_child_samples': 11, 'subsample': 0.7275163351204039}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:24:27,317] Trial 86 finished with value: 3.490951817998576 and parameters: {'max_depth': 11, 'learning_rate': 0.005180355733038494, 'n_estimators': 1420, 'min_child_samples': 18, 'subsample': 0.6181469185681058}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:24:42,657] Trial 87 finished with value: 3.482653713318367 and parameters: {'max_depth': 13, 'learning_rate': 0.007516829447109627, 'n_estimators': 1541, 'min_child_samples': 27, 'subsample': 0.7758523250660111}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:24:58,429] Trial 88 finished with value: 3.481621994694706 and parameters: {'max_depth': 13, 'learning_rate': 0.007588887727935755, 'n_estimators': 1590, 'min_child_samples': 27, 'subsample': 0.7687628603588278}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:25:10,814] Trial 89 finished with value: 3.481219588991592 and parameters: {'max_depth': 13, 'learning_rate': 0.007600201844359317, 'n_estimators': 1210, 'min_child_samples': 27, 'subsample': 0.7712164929120523}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:25:20,228] Trial 90 finished with value: 3.483878062707607 and parameters: {'max_depth': 12, 'learning_rate': 0.007683464082781734, 'n_estimators': 1027, 'min_child_samples': 26, 'subsample': 0.7742029896270813}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:25:32,511] Trial 91 finished with value: 3.472737023992903 and parameters: {'max_depth': 12, 'learning_rate': 0.007495421861115702, 'n_estimators': 1183, 'min_child_samples': 27, 'subsample': 0.7749955826809881}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:25:42,391] Trial 92 finished with value: 3.4803295574987616 and parameters: {'max_depth': 13, 'learning_rate': 0.007568234441064731, 'n_estimators': 903, 'min_child_samples': 31, 'subsample': 0.8101463333626869}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:25:52,948] Trial 93 finished with value: 3.4972179869997015 and parameters: {'max_depth': 13, 'learning_rate': 0.00956741465314939, 'n_estimators': 1220, 'min_child_samples': 33, 'subsample': 0.807698542137913}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:26:02,941] Trial 94 finished with value: 3.5671320007682517 and parameters: {'max_depth': 12, 'learning_rate': 0.0031511936703487167, 'n_estimators': 903, 'min_child_samples': 30, 'subsample': 0.7875252528842243}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:26:14,444] Trial 95 finished with value: 3.479507272242585 and parameters: {'max_depth': 13, 'learning_rate': 0.005184580459713507, 'n_estimators': 1143, 'min_child_samples': 37, 'subsample': 0.8321143503309628}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:26:25,585] Trial 96 finished with value: 3.4777620119215635 and parameters: {'max_depth': 11, 'learning_rate': 0.007651105265382521, 'n_estimators': 1114, 'min_child_samples': 28, 'subsample': 0.7990475456849736}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:26:35,307] Trial 97 finished with value: 3.5780979448742136 and parameters: {'max_depth': 11, 'learning_rate': 0.0025289669975476735, 'n_estimators': 1111, 'min_child_samples': 37, 'subsample': 0.8260406954993595}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:26:44,936] Trial 98 finished with value: 4.337746374720013 and parameters: {'max_depth': 11, 'learning_rate': 0.001188741325490341, 'n_estimators': 851, 'min_child_samples': 34, 'subsample': 0.8213893798447899}. Best is trial 23 with value: 3.4664585891590414.
# [I 2023-09-29 07:26:55,793] Trial 99 finished with value: 3.4974610677512943 and parameters: {'max_depth': 12, 'learning_rate': 0.00504402843552832, 'n_estimators': 992, 'min_child_samples': 31, 'subsample': 0.8417856637035297}. Best is trial 23 with value: 3.4664585891590414.

# %%
trial = lgbm_study.best_trial
trial_params = trial.params
print('Best Trial: score {},\nparams {}'.format(trial.value, trial_params))
# params {'max_depth': 15, 'learning_rate': 0.009923129946328227, 'n_estimators': 2990, 'min_child_samples': 7, 'subsample': 0.7602348533033497}

# Best Trial: score 3.4664585891590414,
# params {'max_depth': 12, 'learning_rate': 0.00910508774914054, 'n_estimators': 991, 'min_child_samples': 37, 'subsample': 0.6433832656458656}
# Out:
# Best Trial: score 3.4664585891590414,
# params {'max_depth': 12, 'learning_rate': 0.00910508774914054, 'n_estimators': 991, 'min_child_samples': 37, 'subsample': 0.6433832656458656}

# %% [markdown]
# ## Catboost

# %%
cbrm_study = optuna.create_study(direction='minimize', sampler=TPESampler())
cbrm_study.optimize(cbrm_objective,n_trials=100,timeout = 1800)
# Out:
# [I 2023-09-29 06:24:20,363] A new study created in memory with name: no-name-ddea7a8a-4fe5-43c7-971c-ff6e39cdf461
# [I 2023-09-29 06:25:08,345] Trial 0 finished with value: 3.435101154937121 and parameters: {'iterations': 1068, 'learning_rate': 0.04446312882490412, 'depth': 7, 'l2_leaf_reg': 0.0014826075887738371, 'random_strength': 0.005917714378630867, 'bagging_temperature': 3.497413169140037, 'border_count': 202}. Best is trial 0 with value: 3.435101154937121.
# [W 2023-09-29 07:01:56,603] Trial 1 failed with parameters: {'iterations': 13108, 'learning_rate': 0.013867558544927652, 'depth': 14, 'l2_leaf_reg': 0.00023504241650248919, 'random_strength': 0.13970302795664358, 'bagging_temperature': 8.023846143447654, 'border_count': 213} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "<ipython-input-10-46abfa46d167>", line 59, in cbrm_objective
#     score = cv(x_data=data[x_col],y_data=data[y_col],model=cbrm,metric='mae')
#   File "<ipython-input-7-7dde90367caf>", line 14, in cv
#     model.fit(X_train, y_train)
#   File "/usr/local/lib/python3.10/dist-packages/catboost/core.py", line 5703, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#   File "/usr/local/lib/python3.10/dist-packages/catboost/core.py", line 2319, in _fit
#     self._train(
#   File "/usr/local/lib/python3.10/dist-packages/catboost/core.py", line 1723, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4645, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4694, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2023-09-29 07:01:56,605] Trial 1 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e5d3742188f8> in <cell line: 2>()
#       1 cbrm_study = optuna.create_study(direction='minimize', sampler=TPESampler())
# ----> 2 cbrm_study.optimize(cbrm_objective,n_trials=100,timeout = 1800)
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     440                 If nested invocation of this method occurs.
#     441         """
# --> 442         _optimize(
#     443             study=self,
#     444             func=func,
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64     try:
#      65         if n_jobs == 1:
# ---> 66             _optimize_sequential(
#      67                 study,
#      68                 func,
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             frozen_trial = _run_trial(study, func, catch)
#     164         finally:
#     165             # The following line mitigates memory problems that can be occurred in some
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     249         and not isinstance(func_err, catch)
#     250     ):
# --> 251         raise func_err
#     252     return frozen_trial
#     253
#
# /usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     198     with get_heartbeat_thread(trial._trial_id, study._storage):
#     199         try:
# --> 200             value_or_values = func(trial)
#     201         except exceptions.TrialPruned as e:
#     202             # TODO(mamu): Handle multi-objective cases.
#
# <ipython-input-10-46abfa46d167> in cbrm_objective(trial)
#      57   cbrm = CatBoostRegressor(**cbrm_param)
#      58
# ---> 59   score = cv(x_data=data[x_col],y_data=data[y_col],model=cbrm,metric='mae')
#      60   return score
#
# <ipython-input-7-7dde90367caf> in cv(model, x_data, y_data, metric)
#      12       y_train, y_test = y.iloc[train_index], y.iloc[test_index]
#      13
# ---> 14       model.fit(X_train, y_train)
#      15
#      16       y_pred = model.predict(X_test)
#
# /usr/local/lib/python3.10/dist-packages/catboost/core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5701             CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
#    5702
# -> 5703         return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#    5704                          use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5705                          verbose_eval, metric_period, silent, early_stopping_rounds,
#
# /usr/local/lib/python3.10/dist-packages/catboost/core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2317         with log_fixup(log_cout, log_cerr), \
#    2318             plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2319             self._train(
#    2320                 train_pool,
#    2321                 train_params["eval_sets"],
#
# /usr/local/lib/python3.10/dist-packages/catboost/core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1721
#    1722     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1723         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1724         self._set_trained_model_attributes()
#    1725
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
trial = cbrm_study.best_trial
trial_params = trial.params
print('Best Trial: score {},\nparams {}'.format(trial.value, trial_params))
